# %% [markdown]
# # 04 — Calibration Analysis
#
# Computes calibration statistics on `candidate_level_discrete.csv`.
#
# **Sections:**
# 1. Domain gap test: sports vs. political overpricing in the (0.02, 0.15) band.
# 2. Favorites band calibration (>50¢) with sub-band breakdown.
# 3. Fine sub-band calibration: nine price bands across the full range.
#
# **Reads:** `data/candidate_level_discrete.csv`
# **Writes:** console / table output only

# %%
import sys, os
sys.path.insert(0, os.path.dirname(os.path.abspath('__file__')))
from utils import (clopper_pearson_upper, RNG_SEED, BOOT_REPS,
                   FLOOR_MAX, LS_MAX, FAV_MIN)

import pandas as pd
import numpy as np
from scipy import stats as scipy_stats
import warnings
warnings.filterwarnings('ignore')

BASE_DIR = os.path.abspath('..')
DATA_DIR = os.path.join(BASE_DIR, 'data')

np.random.seed(RNG_SEED)

cand_discrete = pd.read_csv(os.path.join(DATA_DIR, 'candidate_level_discrete.csv'))
print(f'candidate_level_discrete : {len(cand_discrete):,} rows  |  '
      f'{cand_discrete["event"].nunique()} events')
print(f'Domains: {dict(cand_discrete["domain"].value_counts())}')
# Out:
# candidate_level_discrete : 1,239 rows  |  98 events
# Domains: {'Sports': np.int64(802), 'Political': np.int64(437)}

# %%
# ═══════════════════════════════════════════════════════════════════════════
# DOMAIN GAP TEST — Above-floor longshot band (0.02 < price < 0.15)
#
# sports_gap  = win_rate(Sports in band) − mean_implied(Sports in band)
# pol_gap     = win_rate(Political in band) − mean_implied(Political in band)
# diff        = sports_gap − pol_gap
#
# Bootstrap: resample events with replacement (event-clustered, 2000 reps).
# 95% CI on diff via percentile method; significant if CI excludes 0.
# Dataset: cand_discrete (primary, excludes 24 numeric-range events).
# ═══════════════════════════════════════════════════════════════════════════

np.random.seed(RNG_SEED)

print('=' * 72)
print('DOMAIN GAP TEST — Above-floor longshot band (0.02 < price < 0.15)')
print(f'Dataset: cand_discrete  ({cand_discrete["event"].nunique()} discrete-entity events)')
print('=' * 72)
print()

_dg_band = cand_discrete[
    (cand_discrete['snapshot_price'] > FLOOR_MAX) &
    (cand_discrete['snapshot_price'] < 0.15)
].copy()

_dg_sp = _dg_band[_dg_band['domain'] == 'Sports']
_dg_po = _dg_band[_dg_band['domain'] == 'Political']

print('Band composition:')
print(f'  Sports    : {len(_dg_sp):>5,} candidates,  '
      f'{_dg_sp["event"].nunique():>3} events,  {int(_dg_sp["won"].sum()):>3} winners')
print(f'  Political : {len(_dg_po):>5,} candidates,  '
      f'{_dg_po["event"].nunique():>3} events,  {int(_dg_po["won"].sum()):>3} winners')
print()


def _domain_gap(df):
    """win_rate − mean_implied for a sub-frame. Returns nan if empty."""
    if len(df) == 0:
        return float('nan')
    return float(df['won'].mean()) - float(df['snapshot_price'].mean())


_sp_gap_pt  = _domain_gap(_dg_sp)
_po_gap_pt  = _domain_gap(_dg_po)
_diff_pt    = _sp_gap_pt - _po_gap_pt

print('Point estimates:')
print(f'  sports_gap   = win_rate {_dg_sp["won"].mean():.4f} '
      f'− implied {_dg_sp["snapshot_price"].mean():.4f} = {_sp_gap_pt:+.4f}')
print(f'  pol_gap      = win_rate {_dg_po["won"].mean():.4f} '
      f'− implied {_dg_po["snapshot_price"].mean():.4f} = {_po_gap_pt:+.4f}')
print(f'  diff (S − P) = {_diff_pt:+.4f}')
print()

# Event-clustered block bootstrap: resample events (not candidates).
# In each rep, gap is computed on whichever domain-specific candidates
# happen to appear in the resampled event set.
_dg_ev_groups = {
    ev: g.reset_index(drop=True) for ev, g in _dg_band.groupby('event')
}
_dg_evs      = list(_dg_ev_groups.keys())
_dg_boot     = np.full(BOOT_REPS, np.nan)

for _r in range(BOOT_REPS):
    _samp  = np.random.choice(_dg_evs, size=len(_dg_evs), replace=True)
    _bdf   = pd.concat([_dg_ev_groups[_e] for _e in _samp], ignore_index=True)
    _b_sp  = _bdf[_bdf['domain'] == 'Sports']
    _b_po  = _bdf[_bdf['domain'] == 'Political']
    if len(_b_sp) == 0 or len(_b_po) == 0:
        continue   # domain wiped out in this rep — skip (degenerate)
    _dg_boot[_r] = _domain_gap(_b_sp) - _domain_gap(_b_po)

_dg_valid    = _dg_boot[~np.isnan(_dg_boot)]
_dg_n_valid  = len(_dg_valid)
_dg_ci_lo, _dg_ci_hi = np.percentile(_dg_valid, [2.5, 97.5])
_significant = 'YES' if (_dg_ci_lo > 0 or _dg_ci_hi < 0) else 'NO'

print(f'Event-clustered block bootstrap ({BOOT_REPS} reps, {_dg_n_valid} valid):')
print(f'  95% CI on diff (sports_gap − pol_gap): [{_dg_ci_lo:+.4f}, {_dg_ci_hi:+.4f}]')
print(f'  Degenerate reps skipped              : {BOOT_REPS - _dg_n_valid}')
print()
print(f'Domain difference significant at 5%: {_significant}')
# Out:
# ========================================================================
# DOMAIN GAP TEST — Above-floor longshot band (0.02 < price < 0.15)
# Dataset: cand_discrete  (98 discrete-entity events)
# ========================================================================
#
# Band composition:
#   Sports    :   177 candidates,   28 events,    2 winners
#   Political :   102 candidates,   49 events,    5 winners
#
# Point estimates:
#   sports_gap   = win_rate 0.0113 − implied 0.0584 = -0.0471
#   pol_gap      = win_rate 0.0490 − implied 0.0730 = -0.0240
#   diff (S − P) = -0.0230
# Event-clustered block bootstrap (2000 reps, 2000 valid):
#   95% CI on diff (sports_gap − pol_gap): [-0.0695, +0.0175]
#   Degenerate reps skipped              : 0
#
# Domain difference significant at 5%: NO

# %%
from scipy import stats as scipy_stats

def _wilson_ci(k, n, alpha=0.05):
    if n == 0: return float('nan'), float('nan')
    p  = k / n
    z  = scipy_stats.norm.ppf(1 - alpha / 2)
    d  = 1 + z**2 / n
    c  = (p + z**2 / (2 * n)) / d
    m  = z * np.sqrt(p * (1 - p) / n + z**2 / (4 * n**2)) / d
    return c - m, c + m

# ═══════════════════════════════════════════════════════════════════════════
# FAVORITES BAND — Calibration Report
# snapshot_price > 0.50  |  cand_discrete (primary, excludes numeric-range)
# Bootstrap: same event-clustered block logic as _band_stats (defined above).
# ═══════════════════════════════════════════════════════════════════════════

np.random.seed(RNG_SEED)

FAV_LO = 0.50


def _fav_boot_ci(df, reps=BOOT_REPS):
    # Event-clustered bootstrap for win rate on an arbitrary sub-frame.
    n      = len(df)
    n_wins = int(df['won'].sum()) if n else 0
    if n == 0:
        return float('nan'), float('nan'), '-'
    if n_wins == 0:
        return 0.0, clopper_pearson_upper(0, n, alpha=0.05), 'CP'
    ev_g = {ev: g.reset_index(drop=True) for ev, g in df.groupby('event')}
    evs  = list(ev_g.keys())
    boot = []
    for _ in range(reps):
        samp = np.random.choice(evs, size=len(evs), replace=True)
        boot.append(
            float(pd.concat([ev_g[e] for e in samp], ignore_index=True)['won'].mean())
        )
    return float(np.percentile(boot, 2.5)), float(np.percentile(boot, 97.5)), 'bootstrap'


def _fav_stats(df, label):
    n      = len(df)
    n_ev   = int(df['event'].nunique()) if n else 0
    n_wins = int(df['won'].sum())       if n else 0
    imp    = float(df['snapshot_price'].mean()) if n else float('nan')
    wr     = float(df['won'].mean())            if n else float('nan')
    gap    = wr - imp                           if n else float('nan')
    lo, hi, meth = _fav_boot_ci(df)
    wlo, whi     = _wilson_ci(n_wins, n)        if n else (float('nan'), float('nan'))
    return dict(label=label, n=n, n_ev=n_ev, n_wins=n_wins,
                imp=imp, wr=wr, gap=gap,
                lo=lo, hi=hi, meth=meth, wlo=wlo, whi=whi)


# ── Sub-frames ────────────────────────────────────────────────────────────
fav     = cand_discrete[cand_discrete['snapshot_price'] >  FAV_LO].copy()
fav_mid = cand_discrete[(cand_discrete['snapshot_price'] >  0.50) &
                         (cand_discrete['snapshot_price'] <= 0.80)].copy()
fav_hi  = cand_discrete[cand_discrete['snapshot_price'] >  0.80].copy()
fav_sp  = fav[fav['domain'] == 'Sports'].copy()
fav_po  = fav[fav['domain'] == 'Political'].copy()

rows_main = [
    _fav_stats(fav,     'Overall  (> 0.50)     '),
    _fav_stats(fav_mid, '  Sub-band (0.50,0.80]'),
    _fav_stats(fav_hi,  '  Sub-band (0.80,1.00]'),
]
rows_dom = [
    _fav_stats(fav_sp, 'Sports    (> 0.50)'),
    _fav_stats(fav_po, 'Political (> 0.50)'),
]

# ── Formatting helpers ────────────────────────────────────────────────────
def _ci(lo, hi):
    return f'[{lo:.4f},{hi:.4f}]' if not np.isnan(lo) else '      (-)     '

W   = 118
SEP = '  ' + '-' * (W - 2)

# ── Print ─────────────────────────────────────────────────────────────────
print('=' * W)
print('FAVORITES BAND — Calibration Report')
print(f'Dataset: cand_discrete  ({cand_discrete["event"].nunique()} events)  |  '
      f'{BOOT_REPS} bootstrap reps  |  event-clustered CIs')
print('=' * W)

print()
print('PARTS 1 & 3 — Overall and sub-band calibration')
HDR = (f'  {"Band":<26}  {"N_cand":>6}  {"N_ev":>4}  {"N_win":>5}  '
       f'{"Implied":>8}  {"WinRate":>8}  {"Gap":>7}  '
       f'{"Clustered 95%CI":^16}  {"Wilson 95%CI":^16}  CI method')
print(HDR)
print(SEP)
for r in rows_main:
    print(f'  {r["label"]:<26}  {r["n"]:>6,}  {r["n_ev"]:>4}  {r["n_wins"]:>5}  '
          f'{r["imp"]:>8.4f}  {r["wr"]:>8.4f}  {r["gap"]:>+7.4f}  '
          f'{_ci(r["lo"], r["hi"]):^16}  {_ci(r["wlo"], r["whi"]):^16}  {r["meth"]}')

# ── Verdicts ──────────────────────────────────────────────────────────────
ov   = rows_main[0]
cal  = not np.isnan(ov['lo']) and ov['lo'] <= ov['imp'] <= ov['hi']
undp = not np.isnan(ov['lo']) and ov['lo'] > ov['imp']

print()
print('Verdicts (Overall > 0.50):')
print(f'  Consistent with calibration?               '
      f'{"YES" if cal  else "NO "}  '
      f'(implied {ov["imp"]:.4f} {"inside" if cal else "outside"} '
      f'clustered CI {_ci(ov["lo"], ov["hi"])})')
print(f'  Any sign of classic favorite underpricing?  '
      f'{"YES" if undp else "NO "}  '
      f'(CI lower bound {ov["lo"]:.4f} {">" if undp else "<="} implied {ov["imp"]:.4f})')

# ── Domain descriptive ────────────────────────────────────────────────────
print()
print('=' * W)
print('PART 4 — DESCRIPTIVE: by domain (> 0.50 only)')
print('Small per-domain samples; CIs overlap heavily. NOT a domain-difference significance claim.')
HDR2 = (f'  {"Domain":<22}  {"N_cand":>6}  {"N_ev":>4}  {"N_win":>5}  '
        f'{"Implied":>8}  {"WinRate":>8}  {"Gap":>7}  '
        f'{"Clustered 95%CI":^16}  CI method')
print(HDR2)
print('  ' + '-' * 90)
for r in rows_dom:
    print(f'  {r["label"]:<22}  {r["n"]:>6,}  {r["n_ev"]:>4}  {r["n_wins"]:>5}  '
          f'{r["imp"]:>8.4f}  {r["wr"]:>8.4f}  {r["gap"]:>+7.4f}  '
          f'{_ci(r["lo"], r["hi"]):^16}  {r["meth"]}')
print()
print('  Interpret domain gaps as descriptive only.')
# Out:
# ======================================================================================================================
# FAVORITES BAND — Calibration Report
# Dataset: cand_discrete  (98 events)  |  2000 bootstrap reps  |  event-clustered CIs
# ======================================================================================================================
#
# PARTS 1 & 3 — Overall and sub-band calibration
#   Band                        N_cand  N_ev  N_win   Implied   WinRate      Gap  Clustered 95%CI     Wilson 95%CI    CI method
#   --------------------------------------------------------------------------------------------------------------------
#   Overall  (> 0.50)               69    67     57    0.7918    0.8261  +0.0343  [0.7361,0.9104]   [0.7202,0.8976]   bootstrap
#     Sub-band (0.50,0.80]          29    28     19    0.6755    0.6552  -0.0203  [0.4839,0.8276]   [0.4735,0.8006]   bootstrap
#     Sub-band (0.80,1.00]          40    40     38    0.8761    0.9500  +0.0739  [0.8750,1.0000]   [0.8350,0.9862]   bootstrap
#
# Verdicts (Overall > 0.50):
#   Consistent with calibration?               YES  (implied 0.7918 inside clustered CI [0.7361,0.9104])
#   Any sign of classic favorite underpricing?  NO   (CI lower bound 0.7361 <= implied 0.7918)
#
# ======================================================================================================================
# PART 4 — DESCRIPTIVE: by domain (> 0.50 only)
# Small per-domain samples; CIs overlap heavily. NOT a domain-difference significance claim.
#   Domain                  N_cand  N_ev  N_win   Implied   WinRate      Gap  Clustered 95%CI   CI method
#   ------------------------------------------------------------------------------------------
#   Sports    (> 0.50)          19    19     16    0.7784    0.8421  +0.0637  [0.6842,1.0000]   bootstrap
#   Political (> 0.50)          50    48     41    0.7969    0.8200  +0.0231  [0.7169,0.9184]   bootstrap
#
#   Interpret domain gaps as descriptive only.

# %% [markdown]
# ## Fine Calibration by Price Sub-Band
#
# Realized win rate vs mean implied price in nine fine bands across the full range.
# Event-clustered block bootstrap 95% CI (2000 reps) on the gap = win rate − implied.

# %%
# ── Band definitions ──────────────────────────────────────────────────────
# (lo, hi] except the last band which is (lo, 1.00) open on right.
FINE_BANDS = [
    ('(0,2¢]',    0.00, 0.02),
    ('(2,4¢]',    0.02, 0.04),
    ('(4,7¢]',    0.04, 0.07),
    ('(7,15¢]',   0.07, 0.15),
    ('(15,50¢]',  0.15, 0.50),
    ('(50,70¢]',  0.50, 0.70),
    ('(70,80¢]',  0.70, 0.80),
    ('(80,90¢]',  0.80, 0.90),
    ('(90,100¢)', 0.90, 1.00),   # open on right; no prices at exactly 1.00 in data
]

np.random.seed(RNG_SEED)
cand = cand_discrete   # alias for readability below

# ── Bootstrap per band ────────────────────────────────────────────────────
print(f'Running {BOOT_REPS}-rep event-clustered bootstrap for {len(FINE_BANDS)} bands ...')

results = []
for label, lo, hi in FINE_BANDS:
    if hi < 1.00:
        mask = (cand['snapshot_price'] > lo) & (cand['snapshot_price'] <= hi)
    else:
        mask = (cand['snapshot_price'] > lo) & (cand['snapshot_price'] < hi)
    sub = cand[mask].copy()

    n     = len(sub)
    n_ev  = int(sub['event'].nunique()) if n > 0 else 0
    n_win = int(sub['won'].sum())       if n > 0 else 0
    mean_p = float(sub['snapshot_price'].mean()) if n > 0 else float('nan')
    wr     = float(sub['won'].mean())             if n > 0 else float('nan')
    gap    = wr - mean_p                          if n > 0 else float('nan')

    if n == 0:
        ci_lo = ci_hi = float('nan'); method = '-'

    elif n_win == 0:
        # Bootstrap degenerate: all reps give gap = -mean_boot_p (no winners to resample).
        # Report CP upper bound on win rate; gap CI = [0 - mean_p, CP_upper - mean_p].
        cp_hi = clopper_pearson_upper(n)
        ci_lo = 0.0 - mean_p
        ci_hi = cp_hi - mean_p
        method = 'CP'

    else:
        # Event-clustered block bootstrap — fast numpy path
        ev_g = {ev: g for ev, g in sub.groupby('event')}
        evs  = list(ev_g.keys())
        ev_won   = {ev: g['won'].values.astype(float)       for ev, g in ev_g.items()}
        ev_price = {ev: g['snapshot_price'].values.astype(float) for ev, g in ev_g.items()}

        boot_gap = np.empty(BOOT_REPS)
        for r in range(BOOT_REPS):
            samp       = np.random.choice(evs, size=len(evs), replace=True)
            boot_won   = np.concatenate([ev_won[e]   for e in samp])
            boot_price = np.concatenate([ev_price[e] for e in samp])
            boot_gap[r] = boot_won.mean() - boot_price.mean()
        ci_lo, ci_hi = np.percentile(boot_gap, [2.5, 97.5])
        method = 'boot'

    results.append(dict(band=label, n=n, n_ev=n_ev, n_win=n_win,
                        mean_p=mean_p, wr=wr, gap=gap,
                        ci_lo=ci_lo, ci_hi=ci_hi, method=method))

print('Done.')
print()

# ── Compact table ─────────────────────────────────────────────────────────
HDR_W = 107
print('=' * HDR_W)
print('FINE CALIBRATION — discrete-entity set, event-clustered 95% CI on gap (win rate − implied)')
print('  Overpriced: gap < 0 and CI entirely negative.   Underpriced: gap > 0 and CI entirely positive.')
print('=' * HDR_W)
hdr = (f'  {"Band":<12}  {"N":>5}  {"Ev":>4}  {"Win":>4}  '
       f'{"Implied":>8}  {"WinRate":>8}  {"Gap":>8}  '
       f'{"95% CI on gap (win−implied)":^28}  {"CI method"}')
print(hdr)
print('  ' + '-' * (HDR_W - 2))

RD = {r['band']: r for r in results}   # dict for quick lookup in Q&A section

for r in results:
    if np.isnan(r['ci_lo']):
        ci_str = '        (—)        '
    else:
        ci_str = f'[{r["ci_lo"]:>+.4f}, {r["ci_hi"]:>+.4f}]'

    sig_neg = not np.isnan(r['ci_hi']) and r['ci_hi'] < 0
    sig_pos = not np.isnan(r['ci_lo']) and r['ci_lo'] > 0
    flag = '  ← OVERPRICED*' if sig_neg else ('  ← UNDERPRICED*' if sig_pos else '')

    print(f'  {r["band"]:<12}  {r["n"]:>5}  {r["n_ev"]:>4}  {r["n_win"]:>4}  '
          f'{r["mean_p"]:>8.4f}  {r["wr"]:>8.4f}  {r["gap"]:>+8.4f}  '
          f'{ci_str:^28}  {r["method"]}{flag}')

print()
print('  * Sig at 5%: CI on gap excludes zero.')
# Out:
# Running 2000-rep event-clustered bootstrap for 9 bands ...
# Done.
#
# ===========================================================================================================
# FINE CALIBRATION — discrete-entity set, event-clustered 95% CI on gap (win rate − implied)
#   Overpriced: gap < 0 and CI entirely negative.   Underpriced: gap > 0 and CI entirely positive.
# ===========================================================================================================
#   Band              N    Ev   Win   Implied   WinRate       Gap  95% CI on gap (win−implied)   CI method
#   ---------------------------------------------------------------------------------------------------------
#   (0,2¢]          784    76     5    0.0116    0.0064   -0.0052       [-0.0102, +0.0024]       boot
#   (2,4¢]          102    39     2    0.0358    0.0196   -0.0162       [-0.0363, +0.0174]       boot
#   (4,7¢]          100    48     1    0.0575    0.0100   -0.0475       [-0.0587, -0.0233]       boot  ← OVERPRICED*
#   (7,15¢]          85    55     5    0.1128    0.0588   -0.0539       [-0.0947, -0.0019]       boot  ← OVERPRICED*
#   (15,50¢]         99    54    22    0.2664    0.2222   -0.0442       [-0.1068, +0.0206]       boot
#   (50,70¢]         16    15     7    0.6062    0.4375   -0.1687       [-0.3808, +0.0624]       boot
#   (70,80¢]         13    13    12    0.7608    0.9231   +0.1623       [+0.0085, +0.2469]       boot  ← UNDERPRICED*
#   (80,90¢]         32    32    31    0.8587    0.9688   +0.1100       [+0.0469, +0.1453]       boot  ← UNDERPRICED*
#   (90,100¢)         8     8     7    0.9455    0.8750   -0.0705       [-0.3200, +0.0637]       boot
#
#   * Sig at 5%: CI on gap excludes zero.

# %%
# ── Q1 — Longshot uniformity ──────────────────────────────────────────────
print('=' * 80)
print('Q1 — LONGSHOT UNIFORMITY')
print('Is overpricing gap roughly constant across fine longshot bands, or concentrated in (2,4¢]?')
print('=' * 80)
print()

LS_BANDS = ['(2,4¢]', '(4,7¢]', '(7,15¢]']
for bl in LS_BANDS:
    r   = RD[bl]
    sig = (not np.isnan(r['ci_hi'])) and r['ci_hi'] < 0
    print(f'  {bl:<10}  gap={r["gap"]:>+.4f}  '
          f'CI=[{r["ci_lo"]:>+.4f},{r["ci_hi"]:>+.4f}]  '
          f'N={r["n"]:>3} cands / {r["n_ev"]:>2} events / {r["n_win"]} wins  '
          f'  →  {"SIGNIFICANT (CI entirely negative)" if sig else "not sig at 5% (CI straddles zero)"}')

print()
r715 = RD['(7,15¢]']
sig715 = (not np.isnan(r715['ci_hi'])) and r715['ci_hi'] < 0
print('VERDICT Q1:')
print(f'  Does (7,15¢] show significant overpricing on its own?  '
      f'{"YES" if sig715 else "NO"}')
print(f'  (CI upper bound = {r715["ci_hi"]:+.4f}; '
      f'{"entirely below zero — gap real in this band alone" if sig715 else "straddles zero — not independently significant"})')

r24 = RD['(2,4¢]']
sig24 = (not np.isnan(r24['ci_hi'])) and r24['ci_hi'] < 0
r47 = RD['(4,7¢]']
sig47 = (not np.isnan(r47['ci_hi'])) and r47['ci_hi'] < 0

if sig24 and sig47 and sig715:
    print('  Overpricing is spread across all three above-floor longshot bands.')
elif sig715:
    print('  Overpricing is NOT confined to (2,4¢]; it persists at (7,15¢] independently.')
elif not sig24 and not sig47 and not sig715:
    print('  No individual band is independently significant at 5%.')
else:
    print(f'  Pattern: (2,4¢] sig={sig24}, (4,7¢] sig={sig47}, (7,15¢] sig={sig715}.')


# ── Q2 — Favorite top-end ─────────────────────────────────────────────────
print()
print('=' * 80)
print('Q2 — FAVORITE TOP-END: (90,100¢)')
print('Does win rate exceed implied? Does CI exclude the implied price?')
print('=' * 80)
print()

r90 = RD['(90,100¢)']
wr_exceeds  = r90['wr'] > r90['mean_p']
ci_excl_pos = (not np.isnan(r90['ci_lo'])) and r90['ci_lo'] > 0

print(f'  *** THIN SAMPLE: N={r90["n"]} candidates, {r90["n_ev"]} events ***')
print(f'  Implied price : {r90["mean_p"]:.4f} ({r90["mean_p"]*100:.1f}¢)')
print(f'  Win rate      : {r90["wr"]:.4f} ({r90["wr"]*100:.1f}%)')
print(f'  Gap           : {r90["gap"]:+.4f}  '
      f'({"win rate EXCEEDS implied → underpricing direction" if wr_exceeds else "win rate BELOW implied → overpricing direction"})')
print(f'  95% CI on gap : [{r90["ci_lo"]:+.4f}, {r90["ci_hi"]:+.4f}]')
print()
print('VERDICT Q2:')
print(f'  Win rate exceeds implied (underpricing)?   {"YES" if wr_exceeds else "NO"}')
print(f'  CI entirely positive (sig underpricing)?   {"YES" if ci_excl_pos else "NO"}')
print(f'  N={r90["n"]} — too thin for any reliable inference. Do not interpret this band.')
# Out:
# ================================================================================
# Q1 — LONGSHOT UNIFORMITY
# Is overpricing gap roughly constant across fine longshot bands, or concentrated in (2,4¢]?
# ================================================================================
#
#   (2,4¢]      gap=-0.0162  CI=[-0.0363,+0.0174]  N=102 cands / 39 events / 2 wins    →  not sig at 5% (CI straddles zero)
#   (4,7¢]      gap=-0.0475  CI=[-0.0587,-0.0233]  N=100 cands / 48 events / 1 wins    →  SIGNIFICANT (CI entirely negative)
#   (7,15¢]     gap=-0.0539  CI=[-0.0947,-0.0019]  N= 85 cands / 55 events / 5 wins    →  SIGNIFICANT (CI entirely negative)
#
# VERDICT Q1:
#   Does (7,15¢] show significant overpricing on its own?  YES
#   (CI upper bound = -0.0019; entirely below zero — gap real in this band alone)
#   Overpricing is NOT confined to (2,4¢]; it persists at (7,15¢] independently.
#
# ================================================================================
# Q2 — FAVORITE TOP-END: (90,100¢)
# Does win rate exceed implied? Does CI exclude the implied price?
# ================================================================================
#
#   *** THIN SAMPLE: N=8 candidates, 8 events ***
#   Implied price : 0.9455 (94.5¢)
#   Win rate      : 0.8750 (87.5%)
#   Gap           : -0.0705  (win rate BELOW implied → overpricing direction)
#   95% CI on gap : [-0.3200, +0.0637]
#
# VERDICT Q2:
#   Win rate exceeds implied (underpricing)?   NO
#   CI entirely positive (sig underpricing)?   NO
#   N=8 — too thin for any reliable inference. Do not interpret this band.
